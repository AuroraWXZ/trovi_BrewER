# %% [markdown]
# # Part of experiment for BrewER: Entity Resolution On-Demand

# %% [markdown]
# # 1. Environment Configuration
#
# To reproduce the **BrewER** experiment, we first need to reserve a dedicated physical node on the Chameleon testbed.
#
# We will use the `compute_cascadelake_r` node type (Intel Xeon Gold 6240R), which provides sufficient compute power for the entity resolution tasks described in the paper.
#
# **Note:** Ensure you have uploaded your keypair file (e.g., `my_key.pem`) to the Jupyter environment before running this cell.

# %%
import os
import chi

# === CONFIGURATION ===
# Hardware: Intel Xeon Gold 6240R (Cascade Lake Refresh)
NODE_TYPE = "compute_cascadelake_r" 
LEASE_NAME = "brewer_reproduction_lease"
SERVER_NAME = "brewer_experiment_node"

# Update these to match your specific Chameleon keypair
KEY_NAME = "my_key"
KEY_FILE = "my_key.pem"

# Network config (sharednet1 provides internet access)
NETWORK_NAME = "sharednet1"
IMAGE_NAME = "CC-Ubuntu20.04"

# Set the Chameleon site (CHI@UC is standard for this hardware)
chi.use_site("CHI@UC")

print("=== Configuration Check ===")
# Out:
# Now using CHI@UC:
# URL: https://chi.uc.chameleoncloud.org
# Location: Argonne National Laboratory, Lemont, Illinois, USA
# Support contact: help@chameleoncloud.org
# === Configuration Check ===

# %% [markdown]
# # 2. Create Lease (Resource Reservation)
#
# We will now request a **Lease** from Blazar. This reserves:
# 1.  **1 Physical Host:** Dedicated bare metal hardware.
# 2.  **1 Floating IP:** To allow public SSH access to the node.
#
# The lease is set for 1 day to ensure sufficient time to run the `survey_sample` and `sqlite` experiments.

# %%
import time
from datetime import datetime, timedelta
from dateutil import tz
import chi.lease

print("=== Initiating Lease Request ===")

# 1. Define Lease Duration (1 Day)
BLAZAR_TIME_FORMAT = "%Y-%m-%d %H:%M"
# Start 1 minute in the future to allow for processing time
start_date = (datetime.now(tz=tz.tzutc()) + timedelta(minutes=1)).strftime(BLAZAR_TIME_FORMAT)
end_date = (datetime.now(tz=tz.tzutc()) + timedelta(days=1)).strftime(BLAZAR_TIME_FORMAT)

print(f"Start Time: {start_date} (UTC)")
print(f"End Time:   {end_date} (UTC)")

# 2. Build Reservation List
reservation_list = []
chi.lease.add_node_reservation(reservation_list, count=1, node_type=NODE_TYPE)
chi.lease.add_fip_reservation(reservation_list, count=1)

# 3. Submit Lease Request
try:
    lease = chi.lease.create_lease(
        LEASE_NAME,
        start_date=start_date,
        end_date=end_date,
        reservations=reservation_list
    )
    lease_id = lease['id']
    print(f"Lease submitted successfully. ID: {lease_id}")
except Exception as e:
    print(f"Failed to submit lease: {e}")
    raise

# 4. Wait for Lease to become ACTIVE
def wait_for_lease_active(lease_id, timeout=600):
    """
    Polls the lease status until it is ACTIVE or times out.
    """
    print(f"\nWaiting for Lease {lease_id} to start...")
    start_time = time.time()
    
    while time.time() - start_time < timeout:
        try:
            # Get current lease details
            current_lease = chi.lease.get_lease(lease_id)
            
            # Handle response type (Dict vs Object)
            if isinstance(current_lease, dict):
                status = current_lease.get('status')
            else:
                status = getattr(current_lease, 'status', None)
            
            if status == 'ACTIVE':
                print(f"Lease is now ACTIVE! (Time elapsed: {int(time.time() - start_time)}s)")
                return True
            elif status == 'ERROR':
                raise Exception("Lease failed to create (Status: ERROR)")
            else:
                pass 
                
        except Exception as e:
            print(f"Warning during polling: {e}")
        
        time.sleep(10)
        
    raise TimeoutError(f"Timed out waiting for Lease {lease_id}")

# Run the wait function
wait_for_lease_active(lease_id)
# Out:
# The python binding code in neutronclient is deprecated in favor of OpenstackSDK, please use that as this will be removed in a future release.
# === Initiating Lease Request ===
# Start Time: 2026-02-08 03:41 (UTC)
# End Time:   2026-02-09 03:40 (UTC)
# Lease submitted successfully. ID: 3dd65098-78b1-49d7-993f-9bffd5096339
#
# Waiting for Lease 3dd65098-78b1-49d7-993f-9bffd5096339 to start...
# Lease is now ACTIVE! (Time elapsed: 61s)
# True

# %% [markdown]
# # 3. Retrieve Reservation IDs
#
# A lease consists of multiple reservations (one for the compute node, one for the IP). We need to extract the specific **Reservation IDs** to tell Chameleon exactly where to launch our instance in the next step.

# %%
# Extract the specific reservation IDs from the lease object
compute_reservation_id = [
    r['id'] for r in lease['reservations'] 
    if r['resource_type'] == 'physical:host'
][0]

floatingip_reservation_id = [
    r['id'] for r in lease['reservations'] 
    if r['resource_type'] == 'virtual:floatingip'
][0]

print("=== Reservation Details ===")
print(f"Compute Reservation ID:     {compute_reservation_id}")
print(f"Floating IP Reservation ID: {floatingip_reservation_id}")
print("\nReady to launch server.")
# Out:
# === Reservation Details ===
# Compute Reservation ID:     b9c39b55-a497-43e2-9d71-bcdddaaab2d6
# Floating IP Reservation ID: a580a52c-b339-40bf-9d4c-066ebb564eb1
#
# Ready to launch server.

# %% [markdown]
# # 4. Launch Bare Metal Server
#
# Now we provision the physical server using the `compute_reservation_id` we secured earlier.
#
# We are using the `CC-Ubuntu20.04` image, which provides a stable environment for the Python and database dependencies required by BrewER.

# %%
import chi.server

print("=== Launching Bare Metal Server ===")
print(f"Target Reservation: {compute_reservation_id}")

# Create the server bound to our specific reservation
server = chi.server.create_server(
    SERVER_NAME,
    reservation_id=compute_reservation_id,
    network_name=NETWORK_NAME,
    image_name=IMAGE_NAME,
    key_name=KEY_NAME,
    count=1
)

server_id = server.id
print(f"Server provisioning request sent.")
print(f"Server ID: {server_id}")
# Out:
# The python binding code in neutronclient is deprecated in favor of OpenstackSDK, please use that as this will be removed in a future release.
# === Launching Bare Metal Server ===
# Target Reservation: b9c39b55-a497-43e2-9d71-bcdddaaab2d6
# Server provisioning request sent.
# Server ID: 8a131159-ffa1-44f5-8d66-6a846513116b

# %% [markdown]
# # 5. Wait for Active Status & Assign IP
#
# We must wait for the physical hardware to finish provisioning. Once the server status is `ACTIVE`, we associate the **Floating IP**.
#
# This IP address is crucial as it acts as our bridge between this Jupyter notebook and the isolated bare metal node.

# %%
# 1. Wait for the server to provision
print(f"Waiting for Server {server_id} to become ACTIVE...")
chi.server.wait_for_active(server_id)
print("Server hardware is active.")

# 2. Attach Floating IP
print(f"Associating Floating IP...")

# WORKAROUND: We call associate_floating_ip with ONLY the server_id.
# This automatically finds the free IP reserved by your lease and attaches it.
# We do not pass the reservation ID to avoid the library bug.
floating_ip = chi.server.associate_floating_ip(server_id)

print(f"Instance is reachable at: {floating_ip}")
# Out:
# Waiting for Server 8a131159-ffa1-44f5-8d66-6a846513116b to become ACTIVE...
# The python binding code in neutronclient is deprecated in favor of OpenstackSDK, please use that as this will be removed in a future release.
# Server hardware is active.
# Associating Floating IP...
# Instance is reachable at: 192.5.86.206

# %% [markdown]
# # 6. Secure Private Key
#
# SSH clients require private keys to have strict file permissions. We set the key file to `600` (read/write only by owner) to prevent connection errors.

# %%
# Secure the key file permissions
# !chmod 600 {KEY_FILE}

print(f"Permissions secured for {KEY_FILE}")
# Out:
# Permissions secured for my_key.pem

# %% [markdown]
# # 7. Define Remote Execution Helper
#
# To reproduce the BrewER experiments, we need to run commands on the remote server but view the output here in Jupyter.
#
# We define `run_remote`, a helper function that streams standard output (stdout) in real-time. This allows us to monitor long-running processes (like the `sqlite` database build) without staring at a frozen screen.

# %%
import subprocess

def run_remote(command, description=None):
    """
    Runs a shell command on the remote instance via SSH.
    Streams output in real-time so we can watch experiment progress.
    """
    if description:
        print(f"\nExample Step: {description}...")
        print("-" * 40)
    
    ssh_cmd = [
        "ssh", "-i", KEY_FILE,
        "-o", "StrictHostKeyChecking=no",
        "-o", "UserKnownHostsFile=/dev/null",
        f"cc@{floating_ip}",
        command
    ]
    
    # Use Popen to stream output line-by-line
    process = subprocess.Popen(
        ssh_cmd, 
        stdout=subprocess.PIPE, 
        stderr=subprocess.STDOUT, 
        text=True, 
        bufsize=1
    )
    
    # Print output as it arrives
    for line in iter(process.stdout.readline, ''):
        print(line, end='') 
    
    process.stdout.close()
    return_code = process.wait()
    
    if return_code != 0:
        print(f"\nError in step: {description}")
    else:
        print(f"\nSuccess: {description}")

print("SSH remote execution function defined.")
# Out:
# SSH remote execution function defined.

# %% [markdown]
# # 8. Wait for SSH Readiness
#
# Although the server is "Active" (hardware on), the Operating System (Ubuntu) takes time to boot and start the SSH daemon.
#
# We loop and retry the connection until the server is ready to accept commands.

# %%
import time 

# === Clear Old Host Keys ===
# This prevents the "Remote Host Identification Has Changed" error
# by removing the IP from your known_hosts file before connecting.
print(f"Clearing any stale keys for {floating_ip}...")
subprocess.run(
    ["ssh-keygen", "-R", floating_ip], 
    stdout=subprocess.DEVNULL, 
    stderr=subprocess.DEVNULL
)

def wait_for_ssh(ip, key_file, timeout=600):
    """
    Loops and retries SSH connection until the server is genuinely ready.
    """
    print(f"Attempting SSH connection to {ip}...")
    start_time = time.time()
    
    while time.time() - start_time < timeout:
        try:
            # Attempt a simple echo command with a short timeout
            result = subprocess.run(
                [
                    "ssh", "-i", key_file,
                    "-o", "StrictHostKeyChecking=no",
                    "-o", "UserKnownHostsFile=/dev/null",
                    "-o", "ConnectTimeout=5", 
                    f"cc@{ip}",
                    "echo 'ready'"
                ],
                capture_output=True,
                text=True
            )
            
            # Check for success
            if result.returncode == 0 and "ready" in result.stdout:
                print(f"\n SSH is UP! Connected to {ip}")
                return True
            
        except Exception:
            pass # Ignore transient errors during boot
        
        # Wait before retrying
        time.sleep(10)
        print(".", end="", flush=True)

    raise TimeoutError(f"Timed out. Server {ip} is not reachable via SSH.")

# === EXECUTE ===
wait_for_ssh(floating_ip, KEY_FILE)
# Out:
# Clearing any stale keys for 192.5.86.206...
# Attempting SSH connection to 192.5.86.206...
# ................
#  SSH is UP! Connected to 192.5.86.206
# True

# %% [markdown]
# # 9. Install Dependencies & Clone Repository
#
# We need to prepare the Ubuntu environment. This involves:
# 1.  **System Tools:** Installing `git-lfs` (needed for the large datasets) and `pip`.
# 2.  **Cloning Pollock:** We pull the specific `survey_sample` dataset using LFS to save bandwidth.
# 3.  **Python Libraries:** Installing `requirements.txt` and applying a specific fix for the `regex` library to resolve version conflicts with `dateparser`.

# %%
print("=== Setting Up Environment ===")

# 1. System Dependencies
run_remote(
    "sudo apt-get update && sudo apt-get install -y git git-lfs python3-pip",
    description="Installing system tools (git-lfs, pip)"
)

# 2. Cleanup & Clone
run_remote("rm -rf Pollock", description="Removing old repository versions")
run_remote(
    "git clone https://github.com/HPI-Information-Systems/Pollock.git",
    description="Cloning Pollock Repository"
)

# 3. Pull Data (LFS)
run_remote("cd Pollock && git lfs install")
run_remote(
    "cd Pollock && git lfs pull -I 'survey_sample/'",
    description="Downloading 'survey_sample' dataset via LFS"
)

# 4. Python Dependencies
# Fix for regex version conflict (required for dateparser < 2022.3.15)
run_remote(
    "cd Pollock && pip3 install -r requirements.txt && python3 -m pip install 'regex==2022.1.18'",
    description="Installing Python requirements"
)
# Out:
# === Setting Up Environment ===
#
# Example Step: Installing system tools (git-lfs, pip)...
# ----------------------------------------
# Warning: Permanently added '192.5.86.206' (ED25519) to the list of known hosts.
# Hit:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal InRelease
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Get:3 http://security.ubuntu.com/ubuntu focal-security InRelease [128 kB]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports InRelease [128 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3957 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 c-n-f Metadata [18.0 kB]
# Get:7 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [3922 kB]
# Get:8 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/restricted amd64 c-n-f Metadata [604 B]
# Get:9 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1262 kB]
# Get:10 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 c-n-f Metadata [29.3 kB]
# Get:11 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [29.7 kB]
# Get:12 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 c-n-f Metadata [688 B]
# Get:13 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3564 kB]
# Get:14 http://security.ubuntu.com/ubuntu focal-security/main amd64 c-n-f Metadata [14.4 kB]
# Get:15 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 Packages [3768 kB]
# Get:16 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 c-n-f Metadata [584 B]
# Get:17 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1040 kB]
# Get:18 http://security.ubuntu.com/ubuntu focal-security/universe amd64 c-n-f Metadata [22.4 kB]
# Get:19 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [26.6 kB]
# Get:20 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 c-n-f Metadata [604 B]
# Fetched 18.0 MB in 3s (7003 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   python-pip-whl python3-wheel
# Suggested packages:
#   git-daemon-run | git-daemon-sysvinit git-doc git-el git-email git-gui gitk
#   gitweb git-cvs git-mediawiki git-svn
# The following NEW packages will be installed:
#   git-lfs python3-pip python3-wheel
# The following packages will be upgraded:
#   git python-pip-whl
# 2 upgraded, 3 newly installed, 0 to remove and 121 not upgraded.
# Need to get 9992 kB of archives.
# After this operation, 12.3 MB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 git amd64 1:2.25.1-1ubuntu3.14 [4613 kB]
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 git-lfs amd64 2.9.2-1 [3316 kB]
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python-pip-whl all 20.0.2-5ubuntu1.11 [1808 kB]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-wheel all 0.34.2-1ubuntu0.1 [23.9 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-pip all 20.0.2-5ubuntu1.11 [231 kB]
# debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Fetched 9992 kB in 2s (6546 kB/s)
# (Reading database ...
# (Reading database ... 5%
# (Reading database ... 10%
# (Reading database ... 15%
# (Reading database ... 20%
# (Reading database ... 25%
# (Reading database ... 30%
# (Reading database ... 35%
# (Reading database ... 40%
# (Reading database ... 45%
# (Reading database ... 50%
# (Reading database ... 55%
# (Reading database ... 60%
# (Reading database ... 65%
# (Reading database ... 70%
# (Reading database ... 75%
# (Reading database ... 80%
# (Reading database ... 85%
# (Reading database ... 90%
# (Reading database ... 95%
# (Reading database ... 100%
# (Reading database ... 82222 files and directories currently installed.)
# Preparing to unpack .../git_1%3a2.25.1-1ubuntu3.14_amd64.deb ...
# Unpacking git (1:2.25.1-1ubuntu3.14) over (1:2.25.1-1ubuntu3.13) ...
# Selecting previously unselected package git-lfs.
# Preparing to unpack .../git-lfs_2.9.2-1_amd64.deb ...
# Unpacking git-lfs (2.9.2-1) ...
# Preparing to unpack .../python-pip-whl_20.0.2-5ubuntu1.11_all.deb ...
# Unpacking python-pip-whl (20.0.2-5ubuntu1.11) over (20.0.2-5ubuntu1.10) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../python3-wheel_0.34.2-1ubuntu0.1_all.deb ...
# Unpacking python3-wheel (0.34.2-1ubuntu0.1) ...
# Selecting previously unselected package python3-pip.
# Preparing to unpack .../python3-pip_20.0.2-5ubuntu1.11_all.deb ...
# Unpacking python3-pip (20.0.2-5ubuntu1.11) ...
# Setting up python3-wheel (0.34.2-1ubuntu0.1) ...
# Setting up git (1:2.25.1-1ubuntu3.14) ...
# Setting up python-pip-whl (20.0.2-5ubuntu1.11) ...
# Setting up git-lfs (2.9.2-1) ...
# Setting up python3-pip (20.0.2-5ubuntu1.11) ...
# Processing triggers for man-db (2.9.1-1) ...
#
# Success: Installing system tools (git-lfs, pip)
#
# Example Step: Removing old repository versions...
# ----------------------------------------
# Warning: Permanently added '192.5.86.206' (ED25519) to the list of known hosts.
#
# Success: Removing old repository versions
#
# Example Step: Cloning Pollock Repository...
# ----------------------------------------
# Warning: Permanently added '192.5.86.206' (ED25519) to the list of known hosts.
# Cloning into 'Pollock'...
# Updating files:  20% (12302/59512)
# Updating files:  21% (12498/59512)
# Updating files:  22% (13093/59512)
# Updating files:  23% (13688/59512)
# Updating files:  24% (14283/59512)
# Updating files:  25% (14878/59512)
# Updating files:  26% (15474/59512)
# Updating files:  27% (16069/59512)
# Updating files:  28% (16664/59512)
# Updating files:  29% (17259/59512)
# Updating files:  30% (17854/59512)
# Updating files:  31% (18449/59512)
# Updating files:  31% (18758/59512)
# Updating files:  32% (19044/59512)
# Updating files:  33% (19639/59512)
# Updating files:  34% (20235/59512)
# Updating files:  35% (20830/59512)
# Updating files:  36% (21425/59512)
# Updating files:  37% (22020/59512)
# Updating files:  38% (22615/59512)
# Updating files:  39% (23210/59512)
# Updating files:  40% (23805/59512)
# Updating files:  41% (24400/59512)
# Updating files:  42% (24996/59512)
# Updating files:  43% (25591/59512)
# Updating files:  43% (25885/59512)
# Updating files:  44% (26186/59512)
# Updating files:  45% (26781/59512)
# Updating files:  46% (27376/59512)
# Updating files:  47% (27971/59512)
# Updating files:  48% (28566/59512)
# Updating files:  49% (29161/59512)
# Updating files:  50% (29756/59512)
# Updating files:  51% (30352/59512)
# Updating files:  51% (30726/59512)
# Updating files:  52% (30947/59512)
# Updating files:  53% (31542/59512)
# Updating files:  54% (32137/59512)
# Updating files:  55% (32732/59512)
# Updating files:  56% (33327/59512)
# Updating files:  57% (33922/59512)
# Updating files:  58% (34517/59512)
# Updating files:  59% (35113/59512)
# Updating files:  59% (35514/59512)
# Updating files:  60% (35708/59512)
# Updating files:  61% (36303/59512)
# Updating files:  62% (36898/59512)
# Updating files:  63% (37493/59512)
# Updating files:  64% (38088/59512)
# Updating files:  65% (38683/59512)
# Updating files:  66% (39278/59512)
# Updating files:  67% (39874/59512)
# Updating files:  68% (40469/59512)
# Updating files:  69% (41064/59512)
# Updating files:  70% (41659/59512)
# Updating files:  71% (42254/59512)
# Updating files:  72% (42849/59512)
# Updating files:  73% (43444/59512)
# Updating files:  73% (43974/59512)
# Updating files:  74% (44039/59512)
# Updating files:  75% (44634/59512)
# Updating files:  76% (45230/59512)
# Updating files:  77% (45825/59512)
# Updating files:  78% (46420/59512)
# Updating files:  79% (47015/59512)
# Updating files:  80% (47610/59512)
# Updating files:  81% (48205/59512)
# Updating files:  82% (48800/59512)
# Updating files:  83% (49395/59512)
# Updating files:  84% (49991/59512)
# Updating files:  85% (50586/59512)
# Updating files:  86% (51181/59512)
# Updating files:  87% (51776/59512)
# Updating files:  87% (52311/59512)
# Updating files:  88% (52371/59512)
# Updating files:  89% (52966/59512)
# Updating files:  90% (53561/59512)
# Updating files:  91% (54156/59512)
# Updating files:  92% (54752/59512)
# Updating files:  93% (55347/59512)
# Updating files:  94% (55942/59512)
# Updating files:  95% (56537/59512)
# Updating files:  96% (57132/59512)
# Updating files:  97% (57727/59512)
# Updating files:  98% (58322/59512)
# Updating files:  99% (58917/59512)
# Updating files:  99% (59334/59512)
# Updating files: 100% (59512/59512)
# Updating files: 100% (59512/59512), done.
# Filtering content:   3% (111/3676), 19.84 MiB | 15.62 MiB/s
# Filtering content:   4% (148/3676), 19.84 MiB | 15.62 MiB/s
# Filtering content:   5% (184/3676), 21.41 MiB | 11.70 MiB/s
# Filtering content:   5% (200/3676), 21.41 MiB | 11.70 MiB/s
# Filtering content:   5% (213/3676), 22.35 MiB | 7.04 MiB/s
# Filtering content:   6% (221/3676), 22.35 MiB | 7.04 MiB/s
# Filtering content:   7% (258/3676), 71.42 MiB | 20.94 MiB/s
# Filtering content:   7% (285/3676), 82.13 MiB | 20.99 MiB/s
# Filtering content:   8% (295/3676), 82.13 MiB | 20.99 MiB/s
# Filtering content:   9% (331/3676), 87.88 MiB | 18.18 MiB/s
# Filtering content:  10% (368/3676), 94.45 MiB | 17.68 MiB/s
# Filtering content:  10% (403/3676), 94.93 MiB | 13.45 MiB/s
# Filtering content:  11% (405/3676), 94.93 MiB | 13.45 MiB/s
# Filtering content:  12% (442/3676), 94.93 MiB | 13.45 MiB/s
# Filtering content:  12% (468/3676), 106.64 MiB | 14.97 MiB/s
# Filtering content:  13% (478/3676), 106.64 MiB | 14.97 MiB/s
# Filtering content:  13% (505/3676), 108.68 MiB | 13.74 MiB/s
# Filtering content:  14% (515/3676), 108.68 MiB | 13.74 MiB/s
# Filtering content:  14% (543/3676), 137.39 MiB | 11.58 MiB/s
# Filtering content:  15% (552/3676), 137.39 MiB | 11.58 MiB/s
# Filtering content:  16% (589/3676), 137.60 MiB | 9.74 MiB/s
# Filtering content:  16% (604/3676), 310.89 MiB | 30.71 MiB/s
# Filtering content:  16% (605/3676), 317.00 MiB | 29.88 MiB/s
# Filtering content:  16% (607/3676), 317.00 MiB | 29.88 MiB/s
# Filtering content:  16% (619/3676), 359.38 MiB | 36.30 MiB/s
# Filtering content:  17% (625/3676), 398.84 MiB | 39.77 MiB/s
# Filtering content:  18% (662/3676), 473.29 MiB | 53.64 MiB/s
# Filtering content:  18% (675/3676), 473.29 MiB | 53.64 MiB/s
# Filtering content:  19% (699/3676), 473.29 MiB | 53.64 MiB/s
# Filtering content:  19% (709/3676), 478.05 MiB | 49.68 MiB/s
# Filtering content:  20% (736/3676), 495.64 MiB | 52.22 MiB/s
# Filtering content:  21% (772/3676), 495.64 MiB | 52.22 MiB/s
# Filtering content:  21% (801/3676), 496.50 MiB | 37.81 MiB/s
# Filtering content:  22% (809/3676), 500.51 MiB | 37.42 MiB/s
# Filtering content:  22% (838/3676), 500.51 MiB | 37.42 MiB/s
# Filtering content:  23% (846/3676), 507.58 MiB | 33.94 MiB/s
# Filtering content:  24% (883/3676), 507.58 MiB | 33.94 MiB/s
# Filtering content:  24% (905/3676), 509.45 MiB | 21.47 MiB/s
# Filtering content:  25% (919/3676), 509.45 MiB | 21.47 MiB/s
# Filtering content:  25% (927/3676), 535.63 MiB | 12.07 MiB/s
# Filtering content:  26% (956/3676), 535.63 MiB | 12.07 MiB/s
# Filtering content:  27% (993/3676), 537.73 MiB | 12.38 MiB/s
# Filtering content:  27% (1000/3676), 537.78 MiB | 11.76 MiB/s
# Filtering content:  27% (1022/3676), 648.40 MiB | 29.65 MiB/s
# Filtering content:  28% (1030/3676), 655.65 MiB | 30.83 MiB/s
# Filtering content:  29% (1067/3676), 657.80 MiB | 31.51 MiB/s
# Filtering content:  30% (1103/3676), 657.80 MiB | 31.51 MiB/s
# Filtering content:  30% (1105/3676), 661.67 MiB | 25.50 MiB/s
# Filtering content:  30% (1112/3676), 683.19 MiB | 28.37 MiB/s
# Filtering content:  31% (1140/3676), 718.57 MiB | 35.42 MiB/s
# Filtering content:  31% (1163/3676), 762.47 MiB | 37.98 MiB/s
# Filtering content:  32% (1177/3676), 762.47 MiB | 37.98 MiB/s
# Filtering content:  32% (1213/3676), 765.97 MiB | 38.22 MiB/s
# Filtering content:  33% (1214/3676), 765.97 MiB | 38.22 MiB/s
# Filtering content:  34% (1250/3676), 765.97 MiB | 38.22 MiB/s
# Filtering content:  35% (1287/3676), 772.49 MiB | 21.02 MiB/s
# Filtering content:  35% (1305/3676), 772.60 MiB | 18.90 MiB/s
# Filtering content:  36% (1324/3676), 772.60 MiB | 18.90 MiB/s
# Filtering content:  37% (1361/3676), 773.50 MiB | 18.74 MiB/s
# Filtering content:  37% (1377/3676), 773.50 MiB | 18.74 MiB/s
# Filtering content:  38% (1397/3676), 773.56 MiB | 21.87 MiB/s
# Filtering content:  39% (1434/3676), 773.69 MiB | 18.24 MiB/s
# Filtering content:  40% (1471/3676), 774.58 MiB | 11.38 MiB/s
# Filtering content:  40% (1506/3676), 774.60 MiB | 2.50 MiB/s
# Filtering content:  41% (1508/3676), 774.60 MiB | 2.50 MiB/s
# Filtering content:  42% (1544/3676), 775.13 MiB | 2.53 MiB/s
# Filtering content:  43% (1581/3676), 775.63 MiB | 1.99 MiB/s
# Filtering content:  43% (1593/3676), 775.63 MiB | 1.99 MiB/s
# Filtering content:  44% (1618/3676), 775.68 MiB | 647.00 KiB/s
# Filtering content:  44% (1653/3676), 776.58 MiB | 861.00 KiB/s
# Filtering content:  45% (1655/3676), 776.58 MiB | 861.00 KiB/s
# Filtering content:  46% (1691/3676), 776.58 MiB | 861.00 KiB/s
# Filtering content:  46% (1708/3676), 776.81 MiB | 699.00 KiB/s
# Filtering content:  47% (1728/3676), 776.81 MiB | 699.00 KiB/s
# Filtering content:  48% (1765/3676), 779.41 MiB | 1.20 MiB/s
# Filtering content:  49% (1802/3676), 779.41 MiB | 1.20 MiB/s
# Filtering content:  49% (1805/3676), 779.45 MiB | 1.02 MiB/s
# Filtering content:  49% (1822/3676), 779.86 MiB | 1.09 MiB/s
# Filtering content:  50% (1838/3676), 785.72 MiB | 2.17 MiB/s
# Filtering content:  50% (1855/3676), 787.58 MiB | 2.43 MiB/s
# Filtering content:  51% (1875/3676), 817.91 MiB | 8.91 MiB/s
# Filtering content:  51% (1906/3676), 846.89 MiB | 13.58 MiB/s
# Filtering content:  52% (1912/3676), 846.89 MiB | 13.58 MiB/s
# Filtering content:  52% (1938/3676), 851.93 MiB | 14.57 MiB/s
# Filtering content:  53% (1949/3676), 863.98 MiB | 16.76 MiB/s
# Filtering content:  54% (1986/3676), 902.22 MiB | 23.63 MiB/s
# Filtering content:  54% (2006/3676), 902.65 MiB | 22.35 MiB/s
# Filtering content:  55% (2022/3676), 902.65 MiB | 22.35 MiB/s
# Filtering content:  55% (2028/3676), 917.67 MiB | 25.44 MiB/s
# Filtering content:  56% (2059/3676), 917.67 MiB | 25.44 MiB/s
# Filtering content:  57% (2096/3676), 918.54 MiB | 24.67 MiB/s
# Filtering content:  57% (2100/3676), 918.54 MiB | 24.67 MiB/s
# Filtering content:  57% (2105/3676), 1.63 GiB | 44.57 MiB/s
# Filtering content:  58% (2133/3676), 1.63 GiB | 44.57 MiB/s
# Filtering content:  59% (2169/3676), 1.63 GiB | 44.57 MiB/s
# Filtering content:  60% (2206/3676), 1.63 GiB | 44.57 MiB/s
# Filtering content:  60% (2216/3676), 1.64 GiB | 44.63 MiB/s
# Filtering content:  61% (2243/3676), 1.64 GiB | 44.63 MiB/s
# Filtering content:  62% (2280/3676), 1.65 GiB | 44.78 MiB/s
# Filtering content:  62% (2291/3676), 1.65 GiB | 44.39 MiB/s
# Filtering content:  62% (2315/3676), 1.65 GiB | 41.57 MiB/s
# Filtering content:  63% (2316/3676), 1.65 GiB | 41.57 MiB/s
# Filtering content:  64% (2353/3676), 1.69 GiB | 44.26 MiB/s
# Filtering content:  65% (2390/3676), 1.69 GiB | 43.60 MiB/s
# Filtering content:  65% (2391/3676), 1.69 GiB | 43.60 MiB/s
# Filtering content:  65% (2419/3676), 1.69 GiB | 42.99 MiB/s
# Filtering content:  66% (2427/3676), 1.69 GiB | 42.99 MiB/s
# Filtering content:  67% (2463/3676), 1.70 GiB | 43.51 MiB/s
# Filtering content:  68% (2500/3676), 1.70 GiB | 14.88 MiB/s
# Filtering content:  68% (2506/3676), 1.70 GiB | 11.87 MiB/s
# Filtering content:  68% (2536/3676), 1.73 GiB | 14.65 MiB/s
# Filtering content:  69% (2537/3676), 1.73 GiB | 14.65 MiB/s
# Filtering content:  70% (2574/3676), 1.73 GiB | 14.65 MiB/s
# Filtering content:  70% (2607/3676), 1.73 GiB | 14.77 MiB/s
# Filtering content:  71% (2610/3676), 1.73 GiB | 14.77 MiB/s
# Filtering content:  72% (2647/3676), 1.73 GiB | 14.77 MiB/s
# Filtering content:  72% (2666/3676), 1.74 GiB | 9.17 MiB/s
# Filtering content:  73% (2684/3676), 1.74 GiB | 9.17 MiB/s
# Filtering content:  73% (2707/3676), 1.74 GiB | 8.30 MiB/s
# Filtering content:  73% (2710/3676), 1.74 GiB | 8.30 MiB/s
# Filtering content:  73% (2717/3676), 1.77 GiB | 10.08 MiB/s
# Filtering content:  74% (2721/3676), 1.77 GiB | 10.08 MiB/s
# Filtering content:  74% (2751/3676), 1.81 GiB | 17.98 MiB/s
# Filtering content:  75% (2757/3676), 1.81 GiB | 17.98 MiB/s
# Filtering content:  76% (2794/3676), 1.84 GiB | 17.85 MiB/s
# Filtering content:  76% (2807/3676), 1.84 GiB | 17.58 MiB/s
# Filtering content:  76% (2824/3676), 1.94 GiB | 32.98 MiB/s
# Filtering content:  77% (2831/3676), 1.94 GiB | 32.98 MiB/s
# Filtering content:  78% (2868/3676), 1.94 GiB | 32.98 MiB/s
# Filtering content:  79% (2905/3676), 1.94 GiB | 33.29 MiB/s
# Filtering content:  79% (2907/3676), 1.94 GiB | 37.18 MiB/s
# Filtering content:  79% (2938/3676), 1.95 GiB | 37.38 MiB/s
# Filtering content:  80% (2941/3676), 1.95 GiB | 37.38 MiB/s
# Filtering content:  81% (2978/3676), 1.96 GiB | 33.86 MiB/s
# Filtering content:  81% (3007/3676), 1.96 GiB | 26.22 MiB/s
# Filtering content:  82% (3015/3676), 1.96 GiB | 26.22 MiB/s
# Filtering content:  82% (3032/3676), 1.97 GiB | 24.86 MiB/s
# Filtering content:  83% (3052/3676), 1.97 GiB | 24.86 MiB/s
# Filtering content:  84% (3088/3676), 1.99 GiB | 27.61 MiB/s
# Filtering content:  84% (3107/3676), 1.99 GiB | 12.82 MiB/s
# Filtering content:  85% (3125/3676), 1.99 GiB | 12.82 MiB/s
# Filtering content:  85% (3154/3676), 2.01 GiB | 13.47 MiB/s
# Filtering content:  86% (3162/3676), 2.01 GiB | 13.47 MiB/s
# Filtering content:  87% (3199/3676), 2.01 GiB | 13.35 MiB/s
# Filtering content:  87% (3207/3676), 2.01 GiB | 12.68 MiB/s
# Filtering content:  88% (3235/3676), 2.02 GiB | 10.83 MiB/s
# Filtering content:  88% (3241/3676), 2.02 GiB | 10.83 MiB/s
# Filtering content:  89% (3272/3676), 2.02 GiB | 11.47 MiB/s
# Filtering content:  89% (3284/3676), 2.02 GiB | 11.47 MiB/s
# Filtering content:  89% (3304/3676), 2.08 GiB | 12.63 MiB/s
# Filtering content:  89% (3305/3676), 2.26 GiB | 23.69 MiB/s
# Filtering content:  89% (3306/3676), 2.48 GiB | 39.04 MiB/s
# Filtering content:  90% (3309/3676), 2.49 GiB | 38.06 MiB/s
# Filtering content:  90% (3310/3676), 2.49 GiB | 38.06 MiB/s
# Filtering content:  91% (3346/3676), 2.55 GiB | 44.20 MiB/s
# Filtering content:  91% (3349/3676), 2.57 GiB | 45.54 MiB/s
# Filtering content:  92% (3382/3676), 2.57 GiB | 45.54 MiB/s
# Filtering content:  92% (3407/3676), 2.57 GiB | 41.64 MiB/s
# Filtering content:  92% (3416/3676), 2.62 GiB | 44.96 MiB/s
# Filtering content:  93% (3419/3676), 2.62 GiB | 44.96 MiB/s
# Filtering content:  94% (3456/3676), 2.66 GiB | 51.86 MiB/s
# Filtering content:  94% (3491/3676), 2.66 GiB | 57.57 MiB/s
# Filtering content:  95% (3493/3676), 2.66 GiB | 57.57 MiB/s
# Filtering content:  96% (3529/3676), 2.66 GiB | 27.48 MiB/s
# Filtering content:  96% (3530/3676), 2.66 GiB | 27.48 MiB/s
# Filtering content:  97% (3566/3676), 2.66 GiB | 29.08 MiB/s
# Filtering content:  98% (3603/3676), 2.69 GiB | 24.32 MiB/s
# Filtering content:  98% (3608/3676), 2.69 GiB | 21.10 MiB/s
# Filtering content:  99% (3640/3676), 2.69 GiB | 21.10 MiB/s
# Filtering content: 100% (3676/3676), 2.70 GiB | 21.19 MiB/s
# Filtering content: 100% (3676/3676), 2.70 GiB | 28.27 MiB/s, done.
#
# Success: Cloning Pollock Repository
# Warning: Permanently added '192.5.86.206' (ED25519) to the list of known hosts.
# Updated git hooks.
# Git LFS initialized.
#
# Success: None
#
# Example Step: Downloading 'survey_sample' dataset via LFS...
# ----------------------------------------
# Warning: Permanently added '192.5.86.206' (ED25519) to the list of known hosts.
#
# Success: Downloading 'survey_sample' dataset via LFS
#
# Example Step: Installing Python requirements...
# ----------------------------------------
# Warning: Permanently added '192.5.86.206' (ED25519) to the list of known hosts.
# Collecting backports-datetime-fromisoformat==1.0.0
#   Downloading backports-datetime-fromisoformat-1.0.0.tar.gz (10 kB)
# Collecting chardet==4.0.0
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting clevercsv==0.7.4
#   Downloading clevercsv-0.7.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (98 kB)
# Collecting dateparser==1.1.1
#   Downloading dateparser-1.1.1-py2.py3-none-any.whl (288 kB)
# Collecting lxml==4.9.1
#   Downloading lxml-4.9.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.9 MB)
# Collecting multiset==3.0.1
#   Downloading multiset-3.0.1-py2.py3-none-any.whl (9.6 kB)
# Collecting pandas==1.2.2
#   Downloading pandas-1.2.2-cp38-cp38-manylinux1_x86_64.whl (9.7 MB)
# Collecting pqdm==0.2.0
#   Downloading pqdm-0.2.0-py2.py3-none-any.whl (6.8 kB)
# Collecting price-parser==0.3.4
#   Downloading price_parser-0.3.4-py2.py3-none-any.whl (15 kB)
# Collecting scipy==1.5.4
#   Downloading scipy-1.5.4-cp38-cp38-manylinux1_x86_64.whl (25.8 MB)
# Collecting python-dotenv==0.21.1
#   Downloading python_dotenv-0.21.1-py3-none-any.whl (19 kB)
# Collecting joblib==0.17.0
#   Downloading joblib-0.17.0-py3-none-any.whl (301 kB)
# Collecting regex>=2018.11
#   Downloading regex-2024.11.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (785 kB)
# Collecting python-dateutil
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Collecting pytz
#   Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Collecting tzlocal
#   Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Collecting numpy>=1.16.5
#   Downloading numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Collecting tqdm
#   Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Collecting typing-extensions
#   Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
# Collecting bounded-pool-executor
#   Downloading bounded_pool_executor-0.0.3-py3-none-any.whl (3.4 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/lib/python3/dist-packages (from price-parser==0.3.4->-r requirements.txt (line 9)) (19.3.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil->dateparser==1.1.1->-r requirements.txt (line 4)) (1.14.0)
# Collecting backports.zoneinfo; python_version < "3.9"
#   Downloading backports.zoneinfo-0.2.1-cp38-cp38-manylinux1_x86_64.whl (74 kB)
# Building wheels for collected packages: backports-datetime-fromisoformat
#   Building wheel for backports-datetime-fromisoformat (setup.py): started
#   Building wheel for backports-datetime-fromisoformat (setup.py): finished with status 'done'
#   Created wheel for backports-datetime-fromisoformat: filename=backports_datetime_fromisoformat-1.0.0-cp38-cp38-linux_x86_64.whl size=34982 sha256=06e9328c2ccfe4a3bb9b034c11929ccbfb8c62828d35b01368875cd0908e5709
#   Stored in directory: /home/cc/.cache/pip/wheels/eb/f9/c4/5d1bdca20b1fe86e0979c50c212027b871c637e5c93529ff79
# Successfully built backports-datetime-fromisoformat
# Installing collected packages: backports-datetime-fromisoformat, chardet, regex, clevercsv, python-dateutil, pytz, backports.zoneinfo, tzlocal, dateparser, lxml, multiset, numpy, pandas, tqdm, typing-extensions, bounded-pool-executor, pqdm, price-parser, scipy, python-dotenv, joblib
# ERROR: dateparser 1.1.1 has requirement regex!=2019.02.19,!=2021.8.27,<2022.3.15, but you'll have regex 2024.11.6 which is incompatible.
#   WARNING: The script chardetect is installed in '/home/cc/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script clevercsv is installed in '/home/cc/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script dateparser-download is installed in '/home/cc/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts f2py, f2py3 and f2py3.8 are installed in '/home/cc/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tqdm is installed in '/home/cc/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script dotenv is installed in '/home/cc/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed backports-datetime-fromisoformat-1.0.0 backports.zoneinfo-0.2.1 bounded-pool-executor-0.0.3 chardet-4.0.0 clevercsv-0.7.4 dateparser-1.1.1 joblib-0.17.0 lxml-4.9.1 multiset-3.0.1 numpy-1.24.4 pandas-1.2.2 pqdm-0.2.0 price-parser-0.3.4 python-dateutil-2.9.0.post0 python-dotenv-0.21.1 pytz-2025.2 regex-2024.11.6 scipy-1.5.4 tqdm-4.67.3 typing-extensions-4.13.2 tzlocal-5.2
# Collecting regex==2022.1.18
#   Downloading regex-2022.1.18-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (764 kB)
# Installing collected packages: regex
#   Attempting uninstall: regex
#     Found existing installation: regex 2024.11.6
#     Uninstalling regex-2024.11.6:
#       Successfully uninstalled regex-2024.11.6
# Successfully installed regex-2022.1.18
#
# Success: Installing Python requirements

# %% [markdown]
# # 10. Upgrade SQLite (Critical)
#
# The default SQLite version on Ubuntu 20.04 is too old to support some of the `.import --skip` flags used by the reproduction scripts.
#
# We download, compile, and install **SQLite 3.45** from source to ensure the experiment runs without syntax errors.

# %%
print("=== Upgrading SQLite ===")

# Commands to compile SQLite 3.45 from source
upgrade_cmds = [
    "wget -q https://www.sqlite.org/2024/sqlite-autoconf-3450100.tar.gz",
    "tar -xzf sqlite-autoconf-3450100.tar.gz",
    "cd sqlite-autoconf-3450100 && ./configure --quiet && make -j$(nproc) && sudo make install",
    "sudo ldconfig",            # Update shared library cache
    "sqlite3 --version"         # Verify version
]

run_remote(
    " && ".join(upgrade_cmds), 
    description="Compiling and Installing SQLite 3.45"
)
# Out:
# === Upgrading SQLite ===
#
# Example Step: Compiling and Installing SQLite 3.45...
# ----------------------------------------
# Warning: Permanently added '192.5.86.206' (ED25519) to the list of known hosts.
# gcc -DPACKAGE_NAME=\"sqlite\" -DPACKAGE_TARNAME=\"sqlite\" -DPACKAGE_VERSION=\"3.45.1\" -DPACKAGE_STRING=\"sqlite\ 3.45.1\" -DPACKAGE_BUGREPORT=\"http://www.sqlite.org\" -DPACKAGE_URL=\"\" -DPACKAGE=\"sqlite\" -DVERSION=\"3.45.1\" -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_STRINGS_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_UNISTD_H=1 -DSTDC_HEADERS=1 -DHAVE_DLFCN_H=1 -DLT_OBJDIR=\".libs/\" -DHAVE_FDATASYNC=1 -DHAVE_USLEEP=1 -DHAVE_LOCALTIME_R=1 -DHAVE_GMTIME_R=1 -DHAVE_DECL_STRERROR_R=1 -DHAVE_STRERROR_R=1 -DHAVE_POSIX_FALLOCATE=1 -DHAVE_ZLIB_H=1 -I.    -D_REENTRANT=1 -DSQLITE_THREADSAFE=1 -DSQLITE_ENABLE_MATH_FUNCTIONS -DSQLITE_ENABLE_FTS4 -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_GEOPOLY -DSQLITE_HAVE_ZLIB  -DSQLITE_ENABLE_EXPLAIN_COMMENTS -DSQLITE_DQS=0 -DSQLITE_ENABLE_DBPAGE_VTAB -DSQLITE_ENABLE_STMTVTAB -DSQLITE_ENABLE_DBSTAT_VTAB  -g -O2 -MT sqlite3-shell.o -MD -MP -MF .deps/sqlite3-shell.Tpo -c -o sqlite3-shell.o `test -f 'shell.c' || echo './'`shell.c
# gcc -DPACKAGE_NAME=\"sqlite\" -DPACKAGE_TARNAME=\"sqlite\" -DPACKAGE_VERSION=\"3.45.1\" -DPACKAGE_STRING=\"sqlite\ 3.45.1\" -DPACKAGE_BUGREPORT=\"http://www.sqlite.org\" -DPACKAGE_URL=\"\" -DPACKAGE=\"sqlite\" -DVERSION=\"3.45.1\" -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_STRINGS_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_UNISTD_H=1 -DSTDC_HEADERS=1 -DHAVE_DLFCN_H=1 -DLT_OBJDIR=\".libs/\" -DHAVE_FDATASYNC=1 -DHAVE_USLEEP=1 -DHAVE_LOCALTIME_R=1 -DHAVE_GMTIME_R=1 -DHAVE_DECL_STRERROR_R=1 -DHAVE_STRERROR_R=1 -DHAVE_POSIX_FALLOCATE=1 -DHAVE_ZLIB_H=1 -I.    -D_REENTRANT=1 -DSQLITE_THREADSAFE=1 -DSQLITE_ENABLE_MATH_FUNCTIONS -DSQLITE_ENABLE_FTS4 -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_GEOPOLY -DSQLITE_HAVE_ZLIB  -DSQLITE_ENABLE_EXPLAIN_COMMENTS -DSQLITE_DQS=0 -DSQLITE_ENABLE_DBPAGE_VTAB -DSQLITE_ENABLE_STMTVTAB -DSQLITE_ENABLE_DBSTAT_VTAB  -g -O2 -MT sqlite3-sqlite3.o -MD -MP -MF .deps/sqlite3-sqlite3.Tpo -c -o sqlite3-sqlite3.o `test -f 'sqlite3.c' || echo './'`sqlite3.c
# /bin/bash ./libtool  --tag=CC   --mode=compile gcc -DPACKAGE_NAME=\"sqlite\" -DPACKAGE_TARNAME=\"sqlite\" -DPACKAGE_VERSION=\"3.45.1\" -DPACKAGE_STRING=\"sqlite\ 3.45.1\" -DPACKAGE_BUGREPORT=\"http://www.sqlite.org\" -DPACKAGE_URL=\"\" -DPACKAGE=\"sqlite\" -DVERSION=\"3.45.1\" -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_STRINGS_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_UNISTD_H=1 -DSTDC_HEADERS=1 -DHAVE_DLFCN_H=1 -DLT_OBJDIR=\".libs/\" -DHAVE_FDATASYNC=1 -DHAVE_USLEEP=1 -DHAVE_LOCALTIME_R=1 -DHAVE_GMTIME_R=1 -DHAVE_DECL_STRERROR_R=1 -DHAVE_STRERROR_R=1 -DHAVE_POSIX_FALLOCATE=1 -DHAVE_ZLIB_H=1 -I.    -D_REENTRANT=1 -DSQLITE_THREADSAFE=1 -DSQLITE_ENABLE_MATH_FUNCTIONS -DSQLITE_ENABLE_FTS4 -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_GEOPOLY -DSQLITE_HAVE_ZLIB  -g -O2 -MT sqlite3.lo -MD -MP -MF .deps/sqlite3.Tpo -c -o sqlite3.lo sqlite3.c
# libtool: compile:  gcc -DPACKAGE_NAME=\"sqlite\" -DPACKAGE_TARNAME=\"sqlite\" -DPACKAGE_VERSION=\"3.45.1\" "-DPACKAGE_STRING=\"sqlite 3.45.1\"" -DPACKAGE_BUGREPORT=\"http://www.sqlite.org\" -DPACKAGE_URL=\"\" -DPACKAGE=\"sqlite\" -DVERSION=\"3.45.1\" -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_STRINGS_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_UNISTD_H=1 -DSTDC_HEADERS=1 -DHAVE_DLFCN_H=1 -DLT_OBJDIR=\".libs/\" -DHAVE_FDATASYNC=1 -DHAVE_USLEEP=1 -DHAVE_LOCALTIME_R=1 -DHAVE_GMTIME_R=1 -DHAVE_DECL_STRERROR_R=1 -DHAVE_STRERROR_R=1 -DHAVE_POSIX_FALLOCATE=1 -DHAVE_ZLIB_H=1 -I. -D_REENTRANT=1 -DSQLITE_THREADSAFE=1 -DSQLITE_ENABLE_MATH_FUNCTIONS -DSQLITE_ENABLE_FTS4 -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_GEOPOLY -DSQLITE_HAVE_ZLIB -g -O2 -MT sqlite3.lo -MD -MP -MF .deps/sqlite3.Tpo -c sqlite3.c  -fPIC -DPIC -o .libs/sqlite3.o
# mv -f .deps/sqlite3-shell.Tpo .deps/sqlite3-shell.Po
# libtool: compile:  gcc -DPACKAGE_NAME=\"sqlite\" -DPACKAGE_TARNAME=\"sqlite\" -DPACKAGE_VERSION=\"3.45.1\" "-DPACKAGE_STRING=\"sqlite 3.45.1\"" -DPACKAGE_BUGREPORT=\"http://www.sqlite.org\" -DPACKAGE_URL=\"\" -DPACKAGE=\"sqlite\" -DVERSION=\"3.45.1\" -DHAVE_STDIO_H=1 -DHAVE_STDLIB_H=1 -DHAVE_STRING_H=1 -DHAVE_INTTYPES_H=1 -DHAVE_STDINT_H=1 -DHAVE_STRINGS_H=1 -DHAVE_SYS_STAT_H=1 -DHAVE_SYS_TYPES_H=1 -DHAVE_UNISTD_H=1 -DSTDC_HEADERS=1 -DHAVE_DLFCN_H=1 -DLT_OBJDIR=\".libs/\" -DHAVE_FDATASYNC=1 -DHAVE_USLEEP=1 -DHAVE_LOCALTIME_R=1 -DHAVE_GMTIME_R=1 -DHAVE_DECL_STRERROR_R=1 -DHAVE_STRERROR_R=1 -DHAVE_POSIX_FALLOCATE=1 -DHAVE_ZLIB_H=1 -I. -D_REENTRANT=1 -DSQLITE_THREADSAFE=1 -DSQLITE_ENABLE_MATH_FUNCTIONS -DSQLITE_ENABLE_FTS4 -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_GEOPOLY -DSQLITE_HAVE_ZLIB -g -O2 -MT sqlite3.lo -MD -MP -MF .deps/sqlite3.Tpo -c sqlite3.c -o sqlite3.o >/dev/null 2>&1
# mv -f .deps/sqlite3-sqlite3.Tpo .deps/sqlite3-sqlite3.Po
# /bin/bash ./libtool  --tag=CC   --mode=link gcc -D_REENTRANT=1 -DSQLITE_THREADSAFE=1 -DSQLITE_ENABLE_MATH_FUNCTIONS -DSQLITE_ENABLE_FTS4 -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_GEOPOLY -DSQLITE_HAVE_ZLIB  -DSQLITE_ENABLE_EXPLAIN_COMMENTS -DSQLITE_DQS=0 -DSQLITE_ENABLE_DBPAGE_VTAB -DSQLITE_ENABLE_STMTVTAB -DSQLITE_ENABLE_DBSTAT_VTAB  -g -O2   -o sqlite3 sqlite3-shell.o sqlite3-sqlite3.o  -lz -lm -ldl -lpthread
# libtool: link: gcc -D_REENTRANT=1 -DSQLITE_THREADSAFE=1 -DSQLITE_ENABLE_MATH_FUNCTIONS -DSQLITE_ENABLE_FTS4 -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_GEOPOLY -DSQLITE_HAVE_ZLIB -DSQLITE_ENABLE_EXPLAIN_COMMENTS -DSQLITE_DQS=0 -DSQLITE_ENABLE_DBPAGE_VTAB -DSQLITE_ENABLE_STMTVTAB -DSQLITE_ENABLE_DBSTAT_VTAB -g -O2 -o sqlite3 sqlite3-shell.o sqlite3-sqlite3.o  -lz -lm -ldl -lpthread
# mv -f .deps/sqlite3.Tpo .deps/sqlite3.Plo
# /bin/bash ./libtool  --tag=CC   --mode=link gcc -D_REENTRANT=1 -DSQLITE_THREADSAFE=1 -DSQLITE_ENABLE_MATH_FUNCTIONS -DSQLITE_ENABLE_FTS4 -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_GEOPOLY -DSQLITE_HAVE_ZLIB  -g -O2 -no-undefined -version-info 8:6:8  -o libsqlite3.la -rpath /usr/local/lib sqlite3.lo  -lz -lm -ldl -lpthread
# libtool: link: gcc -shared  -fPIC -DPIC  .libs/sqlite3.o   -lz -lm -ldl -lpthread  -g -O2   -Wl,-soname -Wl,libsqlite3.so.0 -o .libs/libsqlite3.so.0.8.6
# libtool: link: (cd ".libs" && rm -f "libsqlite3.so.0" && ln -s "libsqlite3.so.0.8.6" "libsqlite3.so.0")
# libtool: link: (cd ".libs" && rm -f "libsqlite3.so" && ln -s "libsqlite3.so.0.8.6" "libsqlite3.so")
# libtool: link: ar cr .libs/libsqlite3.a  sqlite3.o
# libtool: link: ranlib .libs/libsqlite3.a
# libtool: link: ( cd ".libs" && rm -f "libsqlite3.la" && ln -s "../libsqlite3.la" "libsqlite3.la" )
# make[1]: Entering directory '/home/cc/sqlite-autoconf-3450100'
#  /usr/bin/mkdir -p '/usr/local/lib'
#  /bin/bash ./libtool   --mode=install /usr/bin/install -c   libsqlite3.la '/usr/local/lib'
# libtool: install: /usr/bin/install -c .libs/libsqlite3.so.0.8.6 /usr/local/lib/libsqlite3.so.0.8.6
# libtool: install: (cd /usr/local/lib && { ln -s -f libsqlite3.so.0.8.6 libsqlite3.so.0 || { rm -f libsqlite3.so.0 && ln -s libsqlite3.so.0.8.6 libsqlite3.so.0; }; })
# libtool: install: (cd /usr/local/lib && { ln -s -f libsqlite3.so.0.8.6 libsqlite3.so || { rm -f libsqlite3.so && ln -s libsqlite3.so.0.8.6 libsqlite3.so; }; })
# libtool: install: /usr/bin/install -c .libs/libsqlite3.lai /usr/local/lib/libsqlite3.la
# libtool: install: /usr/bin/install -c .libs/libsqlite3.a /usr/local/lib/libsqlite3.a
# libtool: install: chmod 644 /usr/local/lib/libsqlite3.a
# libtool: install: ranlib /usr/local/lib/libsqlite3.a
# libtool: finish: PATH="/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/snap/bin:/sbin" ldconfig -n /usr/local/lib
# ----------------------------------------------------------------------
# Libraries have been installed in:
#    /usr/local/lib
#
# If you ever happen to want to link against installed libraries
# in a given directory, LIBDIR, you must either use libtool, and
# specify the full pathname of the library, or use the '-LLIBDIR'
# flag during linking and do at least one of the following:
#    - add LIBDIR to the 'LD_LIBRARY_PATH' environment variable
#      during execution
#    - add LIBDIR to the 'LD_RUN_PATH' environment variable
#      during linking
#    - use the '-Wl,-rpath -Wl,LIBDIR' linker flag
#    - have your system administrator add LIBDIR to '/etc/ld.so.conf'
#
# See any operating system documentation about shared libraries for
# more information, such as the ld(1) and ld.so(8) manual pages.
# ----------------------------------------------------------------------
#  /usr/bin/mkdir -p '/usr/local/bin'
#   /bin/bash ./libtool   --mode=install /usr/bin/install -c sqlite3 '/usr/local/bin'
# libtool: install: /usr/bin/install -c sqlite3 /usr/local/bin/sqlite3
#  /usr/bin/mkdir -p '/usr/local/include'
#  /usr/bin/install -c -m 644 sqlite3.h sqlite3ext.h '/usr/local/include'
#  /usr/bin/mkdir -p '/usr/local/share/man/man1'
#  /usr/bin/install -c -m 644 sqlite3.1 '/usr/local/share/man/man1'
#  /usr/bin/mkdir -p '/usr/local/lib/pkgconfig'
#  /usr/bin/install -c -m 644 sqlite3.pc '/usr/local/lib/pkgconfig'
# make[1]: Leaving directory '/home/cc/sqlite-autoconf-3450100'
# 3.45.1 2024-01-30 16:01:20 e876e51a0ed5c5b3126f52e532044363a014bc594cfefa87ffb5b82257cc467a (64-bit)
#
# Success: Compiling and Installing SQLite 3.45

# %% [markdown]
# # 11. Clean & Prepare Workspace
#
# To ensure a fair reproduction, we delete any pre-calculated results that came with the repository and recreate the output directory structure.

# %%
print("=== Preparing Workspace ===")

# 1. Remove existing results to prove we are running it fresh
run_remote("cd Pollock && rm -rf results/*", description="Cleaning old results")

# 2. Create the specific output directory for SQLite results
run_remote(
    "mkdir -p Pollock/results/sqlite/survey_sample/loading", 
    description="Creating output directory structure"
)
# Out:
# === Preparing Workspace ===
#
# Example Step: Cleaning old results...
# ----------------------------------------
# Warning: Permanently added '192.5.86.206' (ED25519) to the list of known hosts.
#
# Success: Cleaning old results
#
# Example Step: Creating output directory structure...
# ----------------------------------------
# Warning: Permanently added '192.5.86.206' (ED25519) to the list of known hosts.
#
# Success: Creating output directory structure

# %% [markdown]
# # 12. Patch & Run BrewER (SQLite)
#
# **Critical Fix:** The original code contains hardcoded absolute paths (e.g., `/results`) designed for a specific Docker container structure. Since we are running on a standard Ubuntu environment, these paths would fail.
#
# We use `sed` to patch the Python files in place, converting absolute paths to relative paths.
#
# Once patched, we execute the **SQLite** method using the specific `sut` script, ensuring the `PYTHONPATH` includes the current directory so Python can find the local modules.

# %%
print("=== Patching & Running Experiment ===")

# 1. Patch Hardcoded Paths (Docker Fix)
print("Applying patches to fix Docker-specific paths...")
# Remove leading slashes to make paths relative
run_remote("sed -i \"s|f'/{dataset}|f'{dataset}|g\" Pollock/sut/sqlite/sqlite.py")
run_remote("sed -i \"s|f'/results|f'results|g\" Pollock/sut/sqlite/sqlite.py")
print("Patches applied.")

# 2. Run Experiment
print("\nExecuting SQLite experiment on 'survey_sample'...")

# We export PYTHONPATH so the script can find 'pollock' modules in the current dir
experiment_cmd = (
    "cd Pollock && "
    "export DATASET=survey_sample && "
    "export PYTHONPATH=$PYTHONPATH:.:$(pwd)/sut && "
    "python3 sut/sqlite/sqlite.py "
    "--dataset survey_sample "
    "--db_type sqlite " 
    "--run_type experiment"
)

run_remote(
    experiment_cmd, 
    description="Running SQLite Experiment"
)
# Out:
# === Patching & Running Experiment ===
# Applying patches to fix Docker-specific paths...
# Warning: Permanently added '192.5.86.206' (ED25519) to the list of known hosts.
#
# Success: None
# Warning: Permanently added '192.5.86.206' (ED25519) to the list of known hosts.
#
# Success: None
# Patches applied.
#
# Executing SQLite experiment on 'survey_sample'...
#
# Example Step: Running SQLite Experiment...
# ----------------------------------------
# Warning: Permanently added '192.5.86.206' (ED25519) to the list of known hosts.
# Columns renamed during .import /home/cc/Pollock/survey_sample/csv/Takakai2008-ch4.csv due to duplicates:
# "?" to "?_2",
# "?" to "?_4"
# Columns renamed during .import /home/cc/Pollock/survey_sample/csv/Takakai2008-ch4.csv due to duplicates:
# "?" to "?_2",
# "?" to "?_4"
# Columns renamed during .import /home/cc/Pollock/survey_sample/csv/Takakai2008-ch4.csv due to duplicates:
# "?" to "?_2",
# "?" to "?_4"
# Columns renamed during .import /home/cc/Pollock/survey_sample/csv/300mAThree.CSV due to duplicates:
# "0" to "0_1",
# "0" to "0_2"
# Columns renamed during .import /home/cc/Pollock/survey_sample/csv/300mAThree.CSV due to duplicates:
# "0" to "0_1",
# "0" to "0_2"
# Columns renamed during .import /home/cc/Pollock/survey_sample/csv/300mAThree.CSV due to duplicates:
# "0" to "0_1",
# "0" to "0_2"
# Columns renamed during .import /home/cc/Pollock/survey_sample/csv/Auto_Tone_sub205_over.csv due to duplicates:
# "1" to "1_1",
# "1" to "1_2",
# "4" to "4_6",
# "4" to "4_7"
# Columns renamed during .import /home/cc/Pollock/survey_sample/csv/Auto_Tone_sub205_over.csv due to duplicates:
# "1" to "1_1",
# "1" to "1_2",
# "4" to "4_6",
# "4" to "4_7"
# Columns renamed during .import /home/cc/Pollock/survey_sample/csv/Auto_Tone_sub205_over.csv due to duplicates:
# "1" to "1_1",
# "1" to "1_2",
# "4" to "4_6",
# "4" to "4_7"
# /home/cc/Pollock/survey_sample/csv/S30out.csv:2: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:3: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:4: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:5: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:6: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:7: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:8: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:9: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:10: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:11: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:12: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:13: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:14: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:15: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:16: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:17: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:18: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:19: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:20: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:21: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:22: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:23: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:24: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:25: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:26: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:27: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:28: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:29: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:30: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:31: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:32: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:33: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:34: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:35: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:36: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:37: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:38: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:39: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:40: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:41: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:42: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:43: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:44: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:45: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:46: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:47: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:48: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:49: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:50: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:51: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:52: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:53: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:54: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:55: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:56: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:57: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:58: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:59: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:60: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:61: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:62: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:63: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:64: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:65: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:66: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:67: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:68: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:69: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:70: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:71: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:72: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:73: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:74: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:75: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:76: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:77: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:78: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:79: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:80: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:81: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:82: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:83: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:84: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:85: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:86: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:87: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:88: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:89: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:90: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:91: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:92: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:93: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:94: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:95: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:96: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:97: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:98: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:99: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:100: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:101: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:102: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:103: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:104: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:105: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:106: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:107: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:108: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:109: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:110: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:111: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:112: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:113: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:114: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:115: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:116: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:117: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:118: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:119: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:120: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:121: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:122: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:123: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:124: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:125: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:126: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:127: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:128: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:129: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:130: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:131: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:132: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:133: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:134: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:135: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:136: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:137: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:138: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:139: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:140: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:141: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:142: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:143: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:144: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:145: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:146: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:147: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:148: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:149: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:150: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:151: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:152: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:153: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:154: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:155: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:156: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:157: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:158: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:159: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:160: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:161: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:162: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:163: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:164: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:165: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:166: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:167: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:168: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:169: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:170: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:171: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:172: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:173: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:174: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:175: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:176: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:177: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:178: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:179: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:180: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:181: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:182: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:183: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:184: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:185: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:186: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:187: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:188: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:189: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:190: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:191: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:192: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:193: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:194: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:195: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:196: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:197: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:198: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:199: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:200: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:201: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:202: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:203: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:204: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:205: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:206: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:207: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:208: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:209: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:210: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:211: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:212: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:213: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:214: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:215: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:216: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:217: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:218: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:219: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:220: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:221: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:222: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:223: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:224: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:225: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:226: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:227: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:228: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:229: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:230: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:231: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:232: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:233: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:234: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:235: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:236: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:237: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:238: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:239: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:240: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:241: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:242: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:243: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:244: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:245: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:246: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:247: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:248: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:249: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:250: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:251: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:252: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:253: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:254: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:255: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:256: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:257: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:258: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:259: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:260: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:261: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:262: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:263: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:264: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:265: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:266: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:267: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:268: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:269: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:270: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:271: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:272: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:273: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:274: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:275: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:276: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:277: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:278: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:279: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:280: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:281: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:282: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:283: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:284: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:285: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:286: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:287: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:288: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:289: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:290: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:291: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:292: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:293: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:294: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:295: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:296: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:297: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:298: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:299: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:300: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:301: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:302: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:303: expected 302 columns but found 902 - extras ignored
# /home/cc/Pollock/survey_sample/csv/S30out.csv:2: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:3: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:4: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:5: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:6: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:7: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:8: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:9: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:10: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:11: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:12: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:13: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:14: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:15: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:16: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:17: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:18: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:19: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:20: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:21: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:22: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:23: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:24: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:25: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:26: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:27: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:28: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:29: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:30: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:31: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:32: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:33: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:34: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:35: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:36: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:37: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:38: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:39: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:40: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:41: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:42: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:43: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:44: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:45: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:46: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:47: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:48: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:49: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:50: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:51: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:52: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:53: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:54: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:55: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:56: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:57: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:58: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:59: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:60: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:61: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:62: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:63: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:64: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:65: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:66: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:67: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:68: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:69: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:70: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:71: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:72: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:73: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:74: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:75: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:76: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:77: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:78: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:79: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:80: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:81: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:82: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:83: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:84: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:85: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:86: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:87: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:88: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:89: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:90: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:91: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:92: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:93: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:94: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:95: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:96: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:97: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:98: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:99: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:100: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:101: expected 302 columns but found 301 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:102: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:103: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:104: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:105: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:106: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:107: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:108: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:109: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:110: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:111: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:112: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:113: expected 302 columns but found 14 - filling the rest with NULL
# /home/cc/Pollock/survey_sample/csv/S30out.csv:114: expected 302 columns but found 14 - filling the rest with NULL
# ...
# /home/cc/Pollock/survey_sample/csv/dd_Wickenburg_nobmp_623.csv:55: expected 1 columns but found 684 - extras ignored
# /home/cc/Pollock/survey_sample/csv/dd_Wickenburg_nobmp_623.csv:56: expected 1 columns but found 684 - extras ignored
# /home/cc/Pollock/survey_sample/csv/dd_Wickenburg_nobmp_623.csv:57: expected 1 columns but found 684 - extras ignored
# /home/cc/Pollock/survey_sample/csv/dd_Wickenburg_nobmp_623.csv:58: expected 1 columns but found 684 - extras ignored
# /home/cc/Pollock/survey_sample/csv/dd_Wickenburg_nobmp_623.csv:59: expected 1 columns but found 684 - extras ignored
# /home/cc/Pollock/survey_sample/csv/dd_Wickenburg_nobmp_623.csv:60: expected 1 columns but found 684 - extras ignored
# /home/cc/Pollock/survey_sample/csv/dd_Wickenburg_nobmp_623.csv:61: expected 1 columns but found 684 - extras ignored
# /home/cc/Pollock/survey_sample/csv/dd_Wickenburg_nobmp_623.csv:62: expected 1 columns but found 684 - extras ignored
# /home/cc/Pollock/survey_sample/csv/dd_Wickenburg_nobmp_623.csv:63: expected 1 columns but found 684 - extras ignored
# /home/cc/Pollock/survey_sample/csv/dd_Wickenburg_nobmp_623.csv:64: expected 1 columns but found 684 - extras ignored
# /home/cc/Pollock/survey_sample/csv/dd_Wickenburg_nobmp_623.csv:65: expected 1 columns but found 684 - extras ignored
# /home/cc/Pollock/survey_sample/csv/dd_Wickenburg_nobmp_623.csv:66: expected 1 columns but found 684 - extras ignored
# /home/cc/Pollock/survey_sample/csv/dd_Wickenburg_nobmp_623.csv:67: expected 1 columns but found 684 - extras ignored
# /home/cc/Pollock/survey_sample/csv/dd_Wickenburg_nobmp_623.csv:68: expected 1 columns but found 684 - extras ignored
# /home/cc/Pollock/survey_sample/csv/dd_Wickenburg_nobmp_623.csv:69: expected 1 columns but found 684 - extras ignored
# /home/cc/Pollock/survey_sample/csv/dd_Wickenburg_nobmp_623.csv:70: expected 1 columns but found 684 - extras ignored
# /home/cc/Pollock/survey_sample/csv/dd_Wickenburg_nobmp_623.csv:71: expected 1 columns but found 684 - extras ignored
# /home/cc/Pollock/survey_sample/csv/dd_Wickenburg_nobmp_623.csv:72: expected 1 columns but found 684 - extras ignored
# /home/cc/Pollock/survey_sample/csv/dd_Wickenburg_nobmp_623.csv:73: expected 1 columns but found 684 - extras ignored
# /home/cc/Pollock/survey_sample/csv/dd_Wickenburg_nobmp_623.csv:74: expected 1 columns but found 684 - extras ignored
# Columns renamed during .import /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv due to duplicates:
# "x" to "x_1",
# "x" to "x_2",
# "x" to "x_3",
# "x" to "x_4",
# "x" to "x_5",
# "x" to "x_6",
# "x" to "x_7",
# "x" to "x_8",
# "x" to "x_9",
# "x" to "x_10",
# "x" to "x_11",
# "x" to "x_12",
# "x" to "x_13",
# "x" to "x_14",
# "x" to "x_15",
# "x" to "x_16",
# "x" to "x_17",
# "x" to "x_18",
# "x" to "x_19",
# "x" to "x_20",
# "x" to "x_21",
# "x" to "x_22",
# "x" to "x_23",
# "x" to "x_24",
# "x" to "x_25",
# "x" to "x_26",
# "x" to "x_27",
# "x" to "x_28",
# "x" to "x_29",
# "x" to "x_30",
# "x" to "x_31",
# "x" to "x_32",
# "x" to "x_33",
# "x" to "x_34",
# "x" to "x_35",
# "x" to "x_36",
# "x" to "x_37",
# "x" to "x_38",
# "x" to "x_39",
# "x" to "x_40",
# "x" to "x_41",
# "x" to "x_42",
# "x" to "x_43",
# "x" to "x_44",
# "x" to "x_45",
# "x" to "x_46",
# "x" to "x_47",
# "x" to "x_48",
# "x" to "x_49",
# "x" to "x_50",
# "x" to "x_51",
# "x" to "x_52",
# "x" to "x_53",
# "x" to "x_54",
# "x" to "x_55",
# "x" to "x_56",
# "x" to "x_57",
# "x" to "x_58",
# "x" to "x_59",
# "x" to "x_60",
# "x" to "x_61",
# "x" to "x_62",
# "x" to "x_63",
# "x" to "x_64",
# "x" to "x_65",
# "x" to "x_66",
# "x" to "x_67",
# "x" to "x_68",
# "x" to "x_69",
# "x" to "x_70",
# "x" to "x_71",
# "x" to "x_72",
# "x" to "x_73",
# "x" to "x_74",
# "x" to "x_75",
# "x" to "x_76",
# "x" to "x_77",
# "x" to "x_78",
# "x" to "x_79",
# "x" to "x_80",
# "x" to "x_81",
# "x" to "x_82",
# "x" to "x_83",
# "x" to "x_84",
# "x" to "x_85",
# "x" to "x_86",
# "x" to "x_87",
# "x" to "x_88",
# "x" to "x_89",
# "x" to "x_90",
# "x" to "x_91",
# "x" to "x_92",
# "x" to "x_93",
# "x" to "x_94",
# "x" to "x_95",
# "x" to "x_96",
# "x" to "x_97",
# "x" to "x_98",
# "x" to "x_99",
# "x" to "x_100",
# "Load" to "Load_101",
# "Load" to "Load_102",
# "Load" to "Load_103",
# "Load" to "Load_104",
# "Load" to "Load_105",
# "Load" to "Load_106",
# "Load" to "Load_107",
# "Load" to "Load_108",
# "Load" to "Load_109",
# "Load" to "Load_110",
# "Load" to "Load_111",
# "Load" to "Load_112",
# "Load" to "Load_113"
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:2: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:3: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:4: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:5: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:6: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:7: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:8: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:9: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:10: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:11: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:12: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:13: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:14: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:15: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:16: expected 117 columns but found 118 - extras ignored
# Columns renamed during .import /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv due to duplicates:
# "x" to "x_1",
# "x" to "x_2",
# "x" to "x_3",
# "x" to "x_4",
# "x" to "x_5",
# "x" to "x_6",
# "x" to "x_7",
# "x" to "x_8",
# "x" to "x_9",
# "x" to "x_10",
# "x" to "x_11",
# "x" to "x_12",
# "x" to "x_13",
# "x" to "x_14",
# "x" to "x_15",
# "x" to "x_16",
# "x" to "x_17",
# "x" to "x_18",
# "x" to "x_19",
# "x" to "x_20",
# "x" to "x_21",
# "x" to "x_22",
# "x" to "x_23",
# "x" to "x_24",
# "x" to "x_25",
# "x" to "x_26",
# "x" to "x_27",
# "x" to "x_28",
# "x" to "x_29",
# "x" to "x_30",
# "x" to "x_31",
# "x" to "x_32",
# "x" to "x_33",
# "x" to "x_34",
# "x" to "x_35",
# "x" to "x_36",
# "x" to "x_37",
# "x" to "x_38",
# "x" to "x_39",
# "x" to "x_40",
# "x" to "x_41",
# "x" to "x_42",
# "x" to "x_43",
# "x" to "x_44",
# "x" to "x_45",
# "x" to "x_46",
# "x" to "x_47",
# "x" to "x_48",
# "x" to "x_49",
# "x" to "x_50",
# "x" to "x_51",
# "x" to "x_52",
# "x" to "x_53",
# "x" to "x_54",
# "x" to "x_55",
# "x" to "x_56",
# "x" to "x_57",
# "x" to "x_58",
# "x" to "x_59",
# "x" to "x_60",
# "x" to "x_61",
# "x" to "x_62",
# "x" to "x_63",
# "x" to "x_64",
# "x" to "x_65",
# "x" to "x_66",
# "x" to "x_67",
# "x" to "x_68",
# "x" to "x_69",
# "x" to "x_70",
# "x" to "x_71",
# "x" to "x_72",
# "x" to "x_73",
# "x" to "x_74",
# "x" to "x_75",
# "x" to "x_76",
# "x" to "x_77",
# "x" to "x_78",
# "x" to "x_79",
# "x" to "x_80",
# "x" to "x_81",
# "x" to "x_82",
# "x" to "x_83",
# "x" to "x_84",
# "x" to "x_85",
# "x" to "x_86",
# "x" to "x_87",
# "x" to "x_88",
# "x" to "x_89",
# "x" to "x_90",
# "x" to "x_91",
# "x" to "x_92",
# "x" to "x_93",
# "x" to "x_94",
# "x" to "x_95",
# "x" to "x_96",
# "x" to "x_97",
# "x" to "x_98",
# "x" to "x_99",
# "x" to "x_100",
# "Load" to "Load_101",
# "Load" to "Load_102",
# "Load" to "Load_103",
# "Load" to "Load_104",
# "Load" to "Load_105",
# "Load" to "Load_106",
# "Load" to "Load_107",
# "Load" to "Load_108",
# "Load" to "Load_109",
# "Load" to "Load_110",
# "Load" to "Load_111",
# "Load" to "Load_112",
# "Load" to "Load_113"
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:2: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:3: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:4: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:5: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:6: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:7: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:8: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:9: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:10: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:11: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:12: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:13: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:14: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:15: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:16: expected 117 columns but found 118 - extras ignored
# Columns renamed during .import /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv due to duplicates:
# "x" to "x_1",
# "x" to "x_2",
# "x" to "x_3",
# "x" to "x_4",
# "x" to "x_5",
# "x" to "x_6",
# "x" to "x_7",
# "x" to "x_8",
# "x" to "x_9",
# "x" to "x_10",
# "x" to "x_11",
# "x" to "x_12",
# "x" to "x_13",
# "x" to "x_14",
# "x" to "x_15",
# "x" to "x_16",
# "x" to "x_17",
# "x" to "x_18",
# "x" to "x_19",
# "x" to "x_20",
# "x" to "x_21",
# "x" to "x_22",
# "x" to "x_23",
# "x" to "x_24",
# "x" to "x_25",
# "x" to "x_26",
# "x" to "x_27",
# "x" to "x_28",
# "x" to "x_29",
# "x" to "x_30",
# "x" to "x_31",
# "x" to "x_32",
# "x" to "x_33",
# "x" to "x_34",
# "x" to "x_35",
# "x" to "x_36",
# "x" to "x_37",
# "x" to "x_38",
# "x" to "x_39",
# "x" to "x_40",
# "x" to "x_41",
# "x" to "x_42",
# "x" to "x_43",
# "x" to "x_44",
# "x" to "x_45",
# "x" to "x_46",
# "x" to "x_47",
# "x" to "x_48",
# "x" to "x_49",
# "x" to "x_50",
# "x" to "x_51",
# "x" to "x_52",
# "x" to "x_53",
# "x" to "x_54",
# "x" to "x_55",
# "x" to "x_56",
# "x" to "x_57",
# "x" to "x_58",
# "x" to "x_59",
# "x" to "x_60",
# "x" to "x_61",
# "x" to "x_62",
# "x" to "x_63",
# "x" to "x_64",
# "x" to "x_65",
# "x" to "x_66",
# "x" to "x_67",
# "x" to "x_68",
# "x" to "x_69",
# "x" to "x_70",
# "x" to "x_71",
# "x" to "x_72",
# "x" to "x_73",
# "x" to "x_74",
# "x" to "x_75",
# "x" to "x_76",
# "x" to "x_77",
# "x" to "x_78",
# "x" to "x_79",
# "x" to "x_80",
# "x" to "x_81",
# "x" to "x_82",
# "x" to "x_83",
# "x" to "x_84",
# "x" to "x_85",
# "x" to "x_86",
# "x" to "x_87",
# "x" to "x_88",
# "x" to "x_89",
# "x" to "x_90",
# "x" to "x_91",
# "x" to "x_92",
# "x" to "x_93",
# "x" to "x_94",
# "x" to "x_95",
# "x" to "x_96",
# "x" to "x_97",
# "x" to "x_98",
# "x" to "x_99",
# "x" to "x_100",
# "Load" to "Load_101",
# "Load" to "Load_102",
# "Load" to "Load_103",
# "Load" to "Load_104",
# "Load" to "Load_105",
# "Load" to "Load_106",
# "Load" to "Load_107",
# "Load" to "Load_108",
# "Load" to "Load_109",
# "Load" to "Load_110",
# "Load" to "Load_111",
# "Load" to "Load_112",
# "Load" to "Load_113"
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:2: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:3: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:4: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:5: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:6: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:7: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:8: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:9: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:10: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:11: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:12: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:13: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:14: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:15: expected 117 columns but found 118 - extras ignored
# /home/cc/Pollock/survey_sample/csv/ResultsOR30x100-0.75_10.dat__m13.csv:16: expected 117 columns but found 118 - extras ignored
# Columns renamed during .import /home/cc/Pollock/survey_sample/csv/workforce-management-information-dft_201706.csv due to duplicates:
# "?" to "?_5",
# "?" to "?_6",
# "?" to "?_7",
# "?" to "?_8",
# "?" to "?_9",
# "?" to "?_10",
# "?" to "?_11",
# "?" to "?_12",
# "?" to "?_13",
# "?" to "?_14",
# "?" to "?_15",
# "?" to "?_16",
# "?" to "?_17",
# "?" to "?_19",
# "?" to "?_20",
# "?" to "?_21",
# "?" to "?_22",
# "?" to "?_23",
# "?" to "?_24",
# "?" to "?_25",
# "?" to "?_26",
# "?" to "?_27",
# "?" to "?_29",
# "?" to "?_31",
# "?" to "?_32",
# "?" to "?_33",
# "?" to "?_34",
# "?" to "?_35",
# "?" to "?_36",
# "?" to "?_38",
# "?" to "?_39",
# "?" to "?_42"
# Columns renamed during .import /home/cc/Pollock/survey_sample/csv/workforce-management-information-dft_201706.csv due to duplicates:
# "?" to "?_5",
# "?" to "?_6",
# "?" to "?_7",
# "?" to "?_8",
# "?" to "?_9",
# "?" to "?_10",
# "?" to "?_11",
# "?" to "?_12",
# "?" to "?_13",
# "?" to "?_14",
# "?" to "?_15",
# "?" to "?_16",
# "?" to "?_17",
# "?" to "?_19",
# "?" to "?_20",
# "?" to "?_21",
# "?" to "?_22",
# "?" to "?_23",
# "?" to "?_24",
# "?" to "?_25",
# "?" to "?_26",
# "?" to "?_27",
# "?" to "?_29",
# "?" to "?_31",
# "?" to "?_32",
# "?" to "?_33",
# "?" to "?_34",
# "?" to "?_35",
# "?" to "?_36",
# "?" to "?_38",
# "?" to "?_39",
# "?" to "?_42"
# Columns renamed during .import /home/cc/Pollock/survey_sample/csv/workforce-management-information-dft_201706.csv due to duplicates:
# "?" to "?_5",
# "?" to "?_6",
# "?" to "?_7",
# "?" to "?_8",
# "?" to "?_9",
# "?" to "?_10",
# "?" to "?_11",
# "?" to "?_12",
# "?" to "?_13",
# "?" to "?_14",
# "?" to "?_15",
# "?" to "?_16",
# "?" to "?_17",
# "?" to "?_19",
# "?" to "?_20",
# "?" to "?_21",
# "?" to "?_22",
# "?" to "?_23",
# "?" to "?_24",
# "?" to "?_25",
# "?" to "?_26",
# "?" to "?_27",
# "?" to "?_29",
# "?" to "?_31",
# "?" to "?_32",
# "?" to "?_33",
# "?" to "?_34",
# "?" to "?_35",
# "?" to "?_36",
# "?" to "?_38",
# "?" to "?_39",
# "?" to "?_42"
# /home/cc/Pollock/survey_sample/csv/locations-1998.csv: empty file
# Error: in prepare, no such table: table1
# /home/cc/Pollock/survey_sample/csv/locations-1998.csv: empty file
# Error: in prepare, no such table: table1
# /home/cc/Pollock/survey_sample/csv/locations-1998.csv: empty file
# Error: in prepare, no such table: table1
#
# Success: Running SQLite Experiment

# %% [markdown]
# # 13. Verify Outputs
#
# Before running the full evaluation metrics, we perform a quick sanity check to list the generated output files. We expect to see `_converted.csv` files in the results folder.

# %%
print("=== Verifying Output Generation ===")

run_remote(
    "ls -lh Pollock/results/sqlite/survey_sample/loading/ | head -n 5", 
    description="Listing top 5 generated result files"
)
# Out:
# === Verifying Output Generation ===
#
# Example Step: Listing top 5 generated result files...
# ----------------------------------------
# Warning: Permanently added '192.5.86.206' (ED25519) to the list of known hosts.
# total 105M
# -rw-rw-r-- 1 cc cc   33K Feb  8 03:56 0Al-Sn.CSV_converted.csv
# -rw-rw-r-- 1 cc cc   47K Feb  8 03:56 1% SiO2_003.csv_converted.csv
# -rw-rw-r-- 1 cc cc   50K Feb  8 03:56 1% nano+20% micro.csv_converted.csv
# -rw-rw-r-- 1 cc cc  8.3K Feb  8 03:56 10.January_2019.csv_converted.csv
#
# Success: Listing top 5 generated result files

# %% [markdown]
# # 14. Parallel Evaluation
#
# **Note on Evaluation Strategy:** The original repository includes a complex evaluation harness designed to benchmark 17 different systems sequentially. For this reproduction, we focus solely on **SQLite**.
#
# To ensure **robustness** and avoid the overhead of the full harness, we use a custom evaluation script below.
# * It calculates **Precision, Recall, and F1** for Headers, Records, and Cells.
# * **Math Validity:** It uses the *exact same* library functions (`pollock.metrics`) as the original paper, ensuring the math is identical.
# * **Efficiency:** It runs in parallel to process the `survey_sample` files quickly.

# %%
# === SILENT PARALLEL EVALUATION ===
print("=== Running Evaluation Metrics ===")

# This script redirects worker output to /dev/null to prevent SSH deadlocks
silent_eval_script = r'''
import os
import sys
import pandas as pd
import pollock.metrics as metrics
from concurrent.futures import ProcessPoolExecutor, as_completed, TimeoutError
import contextlib

# Configuration
DATASET = "survey_sample"
SUT = "sqlite"
CLEAN_DIR = f"{DATASET}/clean"
LOADED_DIR = f"results/{SUT}/{DATASET}/loading"

def evaluate_single_file_silent(filename):
    """Calculates F1 scores for a single file, silencing stdout/stderr."""
    with open(os.devnull, "w") as devnull:
        with contextlib.redirect_stdout(devnull), contextlib.redirect_stderr(devnull):
            clean_path = os.path.join(CLEAN_DIR, filename)
            loaded_path = os.path.join(LOADED_DIR, filename + "_converted.csv")
            
            row = {"file": filename, "success": 0, "header_f1": 0, "record_f1": 0, "cell_f1": 0}
            try:
                if os.path.exists(loaded_path) and os.path.getsize(loaded_path) > 0:
                    if metrics.successful_csv(loaded_path):
                        row["success"] = 1
                        # Exact same math as the original paper:
                        res = metrics.header_record_cell_measures_csv(clean_path, loaded_path, 1)
                        row["header_f1"] = res[2]
                        row["record_f1"] = res[5]
                        row["cell_f1"] = res[8]
            except:
                pass
            return row

if __name__ == "__main__":
    print(f"--- EVALUATING {SUT.upper()} ---", flush=True)

    if not os.path.exists(LOADED_DIR):
        print("Error: No results directory found!")
        exit(1)

    files = [f for f in os.listdir(CLEAN_DIR) if f.endswith(".csv")]
    
    # Use CPU count - 2 to prevent freezing the server
    safe_cores = max(1, (os.cpu_count() or 1) - 2)
    print(f"Processing {len(files)} files using {safe_cores} workers...", flush=True)
    
    results = []
    with ProcessPoolExecutor(max_workers=safe_cores) as executor:
        future_to_file = {executor.submit(evaluate_single_file_silent, f): f for f in files}
        
        try:
            # 60s timeout per file batch
            for i, future in enumerate(as_completed(future_to_file, timeout=60)):
                res = future.result()
                results.append(res)
                if i % 1 == 0: 
                    print(f"[{i+1}/{len(files)}] Processed...", flush=True)
                    
        except TimeoutError:
            print("\nTIMEOUT: Some workers took too long. Calculating partial results.")
            for fut in future_to_file: fut.cancel()

    if not results:
        print("Fatal Error: No files finished successfully.")
        exit(1)

    df = pd.DataFrame(results)

    # VIDEO-FRIENDLY OUTPUT FORMAT
    print("\n" + "="*40)
    print(f" FINAL SCORES: {SUT} on {DATASET}")
    print("="*40)
    print(f"Success Rate:  {df['success'].mean():.2%}")
    print(f"Header F1:     {df['header_f1'].mean():.4f}")
    print(f"Record F1:     {df['record_f1'].mean():.4f}")
    print(f"Cell F1:       {df['cell_f1'].mean():.4f}")
    print("="*40 + "\n")
'''

# 1. Write the script to a local file
with open("silent_eval.py", "w") as f:
    f.write(silent_eval_script)

# 2. Pipe the script to the remote server and execute it
# We use 'cat' to pipe the file content into python3 on the remote end
cmd = f"cat silent_eval.py | ssh -i {KEY_FILE} -o StrictHostKeyChecking=no cc@{floating_ip} 'cd Pollock && python3 -'"

# 3. Run using subprocess
print("Sending evaluation script to remote server...")
subprocess.run(cmd, shell=True)
# Out:
# === Running Evaluation Metrics ===
# Sending evaluation script to remote server...
# Warning: Permanently added '192.5.86.206' (ED25519) to the list of known hosts.
# --- EVALUATING SQLITE ---
# Processing 97 files using 94 workers...
# [1/97] Processed...
# [2/97] Processed...
# [3/97] Processed...
# [4/97] Processed...
# [5/97] Processed...
# [6/97] Processed...
# [7/97] Processed...
# [8/97] Processed...
# [9/97] Processed...
# [10/97] Processed...
# [11/97] Processed...
# [12/97] Processed...
# [13/97] Processed...
# [14/97] Processed...
# [15/97] Processed...
# [16/97] Processed...
# [17/97] Processed...
# [18/97] Processed...
# [19/97] Processed...
# [20/97] Processed...
# [21/97] Processed...
# [22/97] Processed...
# [23/97] Processed...
# [24/97] Processed...
# [25/97] Processed...
# [26/97] Processed...
# [27/97] Processed...
# [28/97] Processed...
# [29/97] Processed...
# [30/97] Processed...
# [31/97] Processed...
# [32/97] Processed...
# [33/97] Processed...
# [34/97] Processed...
# [35/97] Processed...
# [36/97] Processed...
# [37/97] Processed...
# [38/97] Processed...
# [39/97] Processed...
# [40/97] Processed...
# [41/97] Processed...
# [42/97] Processed...
# [43/97] Processed...
# [44/97] Processed...
# [45/97] Processed...
# [46/97] Processed...
# [47/97] Processed...
# [48/97] Processed...
# [49/97] Processed...
# [50/97] Processed...
# [51/97] Processed...
# [52/97] Processed...
# [53/97] Processed...
# [54/97] Processed...
# [55/97] Processed...
# [56/97] Processed...
# [57/97] Processed...
# [58/97] Processed...
# [59/97] Processed...
# [60/97] Processed...
# [61/97] Processed...
# [62/97] Processed...
# [63/97] Processed...
# [64/97] Processed...
# [65/97] Processed...
# [66/97] Processed...
# [67/97] Processed...
# [68/97] Processed...
# [69/97] Processed...
# [70/97] Processed...
# [71/97] Processed...
# [72/97] Processed...
# [73/97] Processed...
# [74/97] Processed...
# [75/97] Processed...
# [76/97] Processed...
# [77/97] Processed...
# [78/97] Processed...
# [79/97] Processed...
# [80/97] Processed...
# [81/97] Processed...
# [82/97] Processed...
# [83/97] Processed...
# [84/97] Processed...
# [85/97] Processed...
# [86/97] Processed...
# [87/97] Processed...
# [88/97] Processed...
# [89/97] Processed...
# [90/97] Processed...
# [91/97] Processed...
# [92/97] Processed...
# [93/97] Processed...
# [94/97] Processed...
# [95/97] Processed...
#
# TIMEOUT: Some workers took too long. Calculating partial results.
#
# ========================================
#  FINAL SCORES: sqlite on survey_sample
# ========================================
# Success Rate:  97.89%
# Header F1:     0.6524
# Record F1:     0.7052
# Cell F1:       0.8975
# ========================================
# CompletedProcess(args="cat silent_eval.py | ssh -i my_key.pem -o StrictHostKeyChecking=no cc@192.5.86.206 'cd Pollock && python3 -'", returncode=0)

# %% [markdown]
# # 15. Clean Up Chameleon Resources
# After completing the experiment, all Chameleon Cloud resources must be explicitly released to stop consuming allocation hours and free hardware.
#
# This cleanup process properly terminates the experiment infrastructure:
# - Deletes the server instance: removes the running compute node and releases the GPU
# - Waits for deletion confirmation: polls server status to ensure complete removal before proceeding
# - Deletes the lease reservation: frees the node reservation and automatically releases the floating IP
# - Stops allocation consumption: immediately stops consuming Service Units (SUs) from your project quota

# %%
# Step 1: Delete the Server Instance
print("\n[1/2] Deleting Server Instance...")
chi.server.delete_server(server_id)
print(f"Server deletion requested for ID: {server_id}")

# Wait for server to be fully deleted
timeout = 300
start_time = time.time()
while time.time() - start_time < timeout:
    try:
        chi.server.get_server(server_id)
        time.sleep(5)
    except Exception:
        print("\nServer successfully deleted")
        break

# Step 2: Delete the Lease
print("\n[2/2] Deleting Lease and Freeing Resources...")
chi.lease.delete_lease(lease_id)
print(f"Lease deleted: {LEASE_NAME}")
print("All resources released")
# Out:
# [1/2] Deleting Server Instance...
# Server deletion requested for ID: 8a131159-ffa1-44f5-8d66-6a846513116b
#
# Server successfully deleted
#
# [2/2] Deleting Lease and Freeing Resources...
# Deleted lease 3dd65098-78b1-49d7-993f-9bffd5096339
# Lease deleted: brewer_reproduction_lease
# All resources released
